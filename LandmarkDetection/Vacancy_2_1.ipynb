# %%
import time
import cv2
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import imutils
import matplotlib.image as mpimg
from collections import OrderedDict
from skimage import io, transform
from math import *
import xml.etree.ElementTree as ET 

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from torchvision import datasets, models, transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class Transforms():
    def __init__(self):
        pass
    
    def rotate(self, image, landmarks, angle):
        angle = random.uniform(-angle, +angle)

        transformation_matrix = torch.tensor([
            [+cos(radians(angle)), -sin(radians(angle))], 
            [+sin(radians(angle)), +cos(radians(angle))]
        ])

        image = imutils.rotate(np.array(image), angle)

        landmarks = landmarks - 112
        new_landmarks = np.matmul(landmarks, transformation_matrix)
        new_landmarks = new_landmarks + 112
        return Image.fromarray(image), new_landmarks

    def resize(self, image, landmarks, img_size):
        ###
        landmarks = landmarks / torch.tensor([np.array(image).shape[0]/224, np.array(image).shape[0]/224])
        ###
        image = TF.resize(image, img_size)
        return image, landmarks

    def color_jitter(self, image, landmarks):
        color_jitter = transforms.ColorJitter(brightness=0.3, 
                                              contrast=0.3,
                                              saturation=0.3, 
                                              hue=0.1)
        image = color_jitter(image)
        return image, landmarks

    def crop_face(self, image, landmarks, crops):
        left = int(crops['left'])
        top = int(crops['top'])
        width = int(crops['width'])
        height = int(crops['height'])
        
        if(width > height) :
            left = left - width*0.25
            top = top + height*0.5 - width*0.5 - width*0.25
            width = width*1.5
            height = width
        else :
            top = top - height*0.25
            left = left + width*0.5 - height*0.5 - height*0.25
            height = height*1.5
            width = height

        image = TF.crop(image, top, left, height, width)
        
        img_shape = np.array(image).shape
        landmarks = torch.tensor(landmarks) - torch.tensor([[left, top]])
        #landmarks = landmarks / torch.tensor([img_shape[1], img_shape[0]])
        return image, landmarks

    def __call__(self, image, landmarks, crops):
        image = Image.fromarray(image)
        image, landmarks = self.crop_face(image, landmarks, crops)
        image, landmarks = self.resize(image, landmarks, (224, 224))
        image, landmarks = self.color_jitter(image, landmarks)
        image, landmarks = self.rotate(image, landmarks, angle=10)
        
        image = TF.to_tensor(image)
        image = TF.normalize(image, [0.5], [0.5])
        
        return image, landmarks

# %%
class FaceLandmarksDataset(Dataset):

    def __init__(self, transform=None):
        tree = ET.parse('./300W/labels_300W_new.xml')
        root = tree.getroot()

        self.image_filenames = []
        self.landmarks = []
        self.crops = []
        self.transform = transform
        self.root_dir= './300W'
        
        
        for filename in root[0]:
            landmark = []
            for num in range(68):
                x_coordinate = int(filename[0][num].attrib['x'])
                y_coordinate = int(filename[0][num].attrib['y'])
                landmark.append([x_coordinate, y_coordinate])
            
            y_l = landmark[37][1], landmark[41][1], landmark[38][1], landmark[40][1]  # left eye
            y_r = landmark[43][1], landmark[47][1], landmark[44][1], landmark[46][1]  # right eye
            y_n = landmark[33][1], landmark[51][1] # nose tip to top of mouth
            avg = 0
            for j in range(2) :
                avg = avg - y_l[2*j] + y_l[2*j+1] - y_r[2*j] + y_r[2*j+1]
            avg = avg/4
            val = avg/(-y_n[0]+y_n[1])
            
            if is_closing == True :
                if val> 0.2:
                    continue
            else :
                if val <= 0.2:
                    continue
                
            self.image_filenames.append(os.path.join(self.root_dir, filename.attrib['file']))
            self.crops.append(filename[0].attrib)
            self.landmarks.append(landmark)

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, index):
        image = cv2.imread(self.image_filenames[index], 0)
        landmarks = self.landmarks[index]
        
        if self.transform:
            image, landmarks = self.transform(image, landmarks, self.crops[index])

        #landmarks = landmarks - 0.5

        return image, landmarks
is_closing = False;
dataset_open = FaceLandmarksDataset(Transforms())

# %%
# split the dataset into validation and test sets
len_valid_set = int(0.1*len(dataset_open))
len_train_set = len(dataset_open) - len_valid_set

print("The length of Train set is {}".format(len_train_set))
print("The length of Valid set is {}".format(len_valid_set))

train_dataset , valid_dataset,  = torch.utils.data.random_split(dataset_open , [len_train_set, len_valid_set])

# shuffle and batch the datasets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=2, shuffle=True, num_workers=0)
# Out:
# The length of Train set is 3340
# The length of Valid set is 371

# %%
class Network(nn.Module):
    def __init__(self,num_classes=136):
        super().__init__()
        self.model_name='resnet34'
        self.model=models.resnet34(pretrained=False)
        self.model.conv1=nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=2, bias=False)
        self.model.fc=nn.Linear(self.model.fc.in_features, num_classes)
        
    def forward(self, x):
        x=self.model(x)
        return x

# %%
import sys

def print_overwrite(step, total_step, loss, operation):
    sys.stdout.write('\r')
    if operation == 'train':
        sys.stdout.write("Train Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))   
    else:
        sys.stdout.write("Valid Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))
        
    sys.stdout.flush()

# %%
torch.autograd.set_detect_anomaly(True)
network = Network()
network.cuda()    

criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(network.parameters(), lr=0.0001)

loss_min = np.inf
num_epochs = 100

start_time = time.time()
train_losses = []
valid_losses = []
for epoch in range(1,num_epochs+1):
    epoch_time = time.time()
    loss_train = 0
    loss_valid = 0
    running_loss = 0
    
    network.train()
    for step in range(1,len(train_loader)+1):
    
        images, landmarks = next(iter(train_loader))
        
        images = images.cuda()
        landmarks = landmarks.view(landmarks.size(0),-1).cuda() 
        
        predictions = network(images)
        
        # clear all the gradients before calculating them
        optimizer.zero_grad()
        
        # find the loss for the current step
        loss_train_step = criterion(predictions, landmarks)
        
        # calculate the gradients
        loss_train_step.backward()
        
        # update the parameters
        optimizer.step()
        
        loss_train += loss_train_step.item()
        running_loss = loss_train/step
        
        print_overwrite(step, len(train_loader), running_loss, 'train')
        
    network.eval() 
    with torch.no_grad():
        
        for step in range(1,len(valid_loader)+1):
            
            images, landmarks = next(iter(valid_loader))
        
            images = images.cuda()
            landmarks = landmarks.view(landmarks.size(0),-1).cuda()
        
            predictions = network(images)

            # find the loss for the current step
            loss_valid_step = criterion(predictions, landmarks)

            loss_valid += loss_valid_step.item()
            running_loss = loss_valid/step

            print_overwrite(step, len(valid_loader), running_loss, 'valid')
    
    loss_train /= len(train_loader)
    loss_valid /= len(valid_loader)
    train_losses.insert(epoch, loss_train)
    valid_losses.insert(epoch, loss_valid)
    print('\n--------------------------------------------------')
    print('Epoch: {}  Train Loss: {:.4f}  Valid Loss: {:.4f}'.format(epoch, loss_train, loss_valid))
    print('--------------------------------------------------')
    
    if loss_valid < loss_min:
        loss_min = loss_valid
        torch.save(network.state_dict(), 'Vacancy_3.pth') # 1 : dataset : 300W & openCVDNN, network : resnet34(3,1,2), preprocess : 50% of openCVDNN
                                                          # 2 : dataset 3219->3816(multi-face images not ommitted)
                                                          # 3 : dataset split (open only)

        print("\nMinimum Validation Loss of {:.4f} at epoch {}/{}".format(loss_min, epoch, num_epochs))
        print('Model Saved\n')
        print("Total Elapsed Time : {} s".format(time.time()-epoch_time))
     
print('Training Complete')
print("Total Elapsed Time : {} s".format(time.time()-start_time))
# Out:
# Valid Steps: 186/186  Loss: 94.0235
# --------------------------------------------------
# Epoch: 1  Train Loss: 107.8637  Valid Loss: 94.0235
# --------------------------------------------------
#
# Minimum Validation Loss of 94.0235 at epoch 1/100
# Model Saved
#
# Total Elapsed Time : 141.00971913337708 s
# Valid Steps: 186/186  Loss: 66.2331
# --------------------------------------------------
# Epoch: 2  Train Loss: 80.7580  Valid Loss: 66.2331
# --------------------------------------------------
#
# Minimum Validation Loss of 66.2331 at epoch 2/100
# Model Saved
#
# Total Elapsed Time : 145.46105241775513 s
# Valid Steps: 186/186  Loss: 39.2613
# --------------------------------------------------
# Epoch: 3  Train Loss: 52.6265  Valid Loss: 39.2613
# --------------------------------------------------
#
# Minimum Validation Loss of 39.2613 at epoch 3/100
# Model Saved
#
# Total Elapsed Time : 145.01891493797302 s
# Valid Steps: 186/186  Loss: 18.5104
# --------------------------------------------------
# Epoch: 4  Train Loss: 28.2809  Valid Loss: 18.5104
# --------------------------------------------------
#
# Minimum Validation Loss of 18.5104 at epoch 4/100
# Model Saved
#
# Total Elapsed Time : 142.4719476699829 s
# Valid Steps: 186/186  Loss: 10.1528
# --------------------------------------------------
# Epoch: 5  Train Loss: 13.9405  Valid Loss: 10.1528
# --------------------------------------------------
#
# Minimum Validation Loss of 10.1528 at epoch 5/100
# Model Saved
#
# Total Elapsed Time : 144.48006343841553 s
# Valid Steps: 186/186  Loss: 7.4415
# --------------------------------------------------
# Epoch: 6  Train Loss: 8.1827  Valid Loss: 7.4415
# --------------------------------------------------
#
# Minimum Validation Loss of 7.4415 at epoch 6/100
# Model Saved
#
# Total Elapsed Time : 143.57282185554504 s
# Valid Steps: 186/186  Loss: 7.4542
# --------------------------------------------------
# Epoch: 7  Train Loss: 7.5504  Valid Loss: 7.4542
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.3450
# --------------------------------------------------
# Epoch: 8  Train Loss: 7.3794  Valid Loss: 7.3450
# --------------------------------------------------
#
# Minimum Validation Loss of 7.3450 at epoch 8/100
# Model Saved
#
# Total Elapsed Time : 143.25826168060303 s
# Valid Steps: 186/186  Loss: 7.2696
# --------------------------------------------------
# Epoch: 9  Train Loss: 7.4747  Valid Loss: 7.2696
# --------------------------------------------------
#
# Minimum Validation Loss of 7.2696 at epoch 9/100
# Model Saved
#
# Total Elapsed Time : 143.56899785995483 s
# Valid Steps: 186/186  Loss: 7.3917
# --------------------------------------------------
# Epoch: 10  Train Loss: 7.4396  Valid Loss: 7.3917
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.4269
# --------------------------------------------------
# Epoch: 11  Train Loss: 7.2745  Valid Loss: 7.4269
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.3223
# --------------------------------------------------
# Epoch: 12  Train Loss: 7.2781  Valid Loss: 7.3223
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.2617
# --------------------------------------------------
# Epoch: 13  Train Loss: 7.2484  Valid Loss: 7.2617
# --------------------------------------------------
#
# Minimum Validation Loss of 7.2617 at epoch 13/100
# Model Saved
#
# Total Elapsed Time : 144.5183207988739 s
# Valid Steps: 186/186  Loss: 7.3422
# --------------------------------------------------
# Epoch: 14  Train Loss: 7.2980  Valid Loss: 7.3422
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.6247
# --------------------------------------------------
# Epoch: 15  Train Loss: 7.3730  Valid Loss: 7.6247
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.3469
# --------------------------------------------------
# Epoch: 16  Train Loss: 7.2648  Valid Loss: 7.3469
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.0914
# --------------------------------------------------
# Epoch: 17  Train Loss: 7.3388  Valid Loss: 7.0914
# --------------------------------------------------
#
# Minimum Validation Loss of 7.0914 at epoch 17/100
# Model Saved
#
# Total Elapsed Time : 144.61161017417908 s
# Valid Steps: 186/186  Loss: 7.1502
# --------------------------------------------------
# Epoch: 18  Train Loss: 7.2705  Valid Loss: 7.1502
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.0107
# --------------------------------------------------
# Epoch: 19  Train Loss: 7.2862  Valid Loss: 7.0107
# --------------------------------------------------
#
# Minimum Validation Loss of 7.0107 at epoch 19/100
# Model Saved
#
# Total Elapsed Time : 143.16482138633728 s
# Valid Steps: 186/186  Loss: 7.3756
# --------------------------------------------------
# Epoch: 20  Train Loss: 7.3073  Valid Loss: 7.3756
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.2595
# --------------------------------------------------
# Epoch: 21  Train Loss: 7.3481  Valid Loss: 7.2595
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.3318
# --------------------------------------------------
# Epoch: 22  Train Loss: 7.3012  Valid Loss: 7.3318
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 7.2463
# --------------------------------------------------
# Epoch: 23  Train Loss: 7.1134  Valid Loss: 7.2463
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 6.6217
# --------------------------------------------------
# Epoch: 24  Train Loss: 6.8924  Valid Loss: 6.6217
# --------------------------------------------------
#
# Minimum Validation Loss of 6.6217 at epoch 24/100
# Model Saved
#
# Total Elapsed Time : 158.91865396499634 s
# Valid Steps: 186/186  Loss: 6.4724
# --------------------------------------------------
# Epoch: 25  Train Loss: 6.5147  Valid Loss: 6.4724
# --------------------------------------------------
#
# Minimum Validation Loss of 6.4724 at epoch 25/100
# Model Saved
#
# Total Elapsed Time : 144.31040692329407 s
# Valid Steps: 186/186  Loss: 6.1029
# --------------------------------------------------
# Epoch: 26  Train Loss: 6.2997  Valid Loss: 6.1029
# --------------------------------------------------
#
# Minimum Validation Loss of 6.1029 at epoch 26/100
# Model Saved
#
# Total Elapsed Time : 145.83921933174133 s
# Valid Steps: 186/186  Loss: 6.0057
# --------------------------------------------------
# Epoch: 27  Train Loss: 6.0104  Valid Loss: 6.0057
# --------------------------------------------------
#
# Minimum Validation Loss of 6.0057 at epoch 27/100
# Model Saved
#
# Total Elapsed Time : 151.52154850959778 s
# Valid Steps: 186/186  Loss: 5.6181
# --------------------------------------------------
# Epoch: 28  Train Loss: 5.8306  Valid Loss: 5.6181
# --------------------------------------------------
#
# Minimum Validation Loss of 5.6181 at epoch 28/100
# Model Saved
#
# Total Elapsed Time : 142.59496116638184 s
# Valid Steps: 186/186  Loss: 5.5026
# --------------------------------------------------
# Epoch: 29  Train Loss: 5.5562  Valid Loss: 5.5026
# --------------------------------------------------
#
# Minimum Validation Loss of 5.5026 at epoch 29/100
# Model Saved
#
# Total Elapsed Time : 142.47012591362 s
# Valid Steps: 186/186  Loss: 5.2023
# --------------------------------------------------
# Epoch: 30  Train Loss: 5.4246  Valid Loss: 5.2023
# --------------------------------------------------
#
# Minimum Validation Loss of 5.2023 at epoch 30/100
# Model Saved
#
# Total Elapsed Time : 144.32766938209534 s
# Valid Steps: 186/186  Loss: 4.8039
# --------------------------------------------------
# Epoch: 31  Train Loss: 5.1498  Valid Loss: 4.8039
# --------------------------------------------------
#
# Minimum Validation Loss of 4.8039 at epoch 31/100
# Model Saved
#
# Total Elapsed Time : 145.68064045906067 s
# Valid Steps: 186/186  Loss: 4.0530
# --------------------------------------------------
# Epoch: 32  Train Loss: 4.6650  Valid Loss: 4.0530
# --------------------------------------------------
#
# Minimum Validation Loss of 4.0530 at epoch 32/100
# Model Saved
#
# Total Elapsed Time : 144.68326544761658 s
# Valid Steps: 186/186  Loss: 3.6497
# --------------------------------------------------
# Epoch: 33  Train Loss: 4.1210  Valid Loss: 3.6497
# --------------------------------------------------
# Minimum Validation Loss of 3.6497 at epoch 33/100
# Model Saved
#
# Total Elapsed Time : 144.06021189689636 s
# Valid Steps: 186/186  Loss: 3.4735
# --------------------------------------------------
# Epoch: 34  Train Loss: 3.8377  Valid Loss: 3.4735
# --------------------------------------------------
#
# Minimum Validation Loss of 3.4735 at epoch 34/100
# Model Saved
#
# Total Elapsed Time : 142.82613897323608 s
# Valid Steps: 186/186  Loss: 3.4783
# --------------------------------------------------
# Epoch: 35  Train Loss: 3.5792  Valid Loss: 3.4783
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 3.2632
# --------------------------------------------------
# Epoch: 36  Train Loss: 3.5142  Valid Loss: 3.2632
# --------------------------------------------------
#
# Minimum Validation Loss of 3.2632 at epoch 36/100
# Model Saved
#
# Total Elapsed Time : 144.95152401924133 s
# Valid Steps: 186/186  Loss: 2.8525
# --------------------------------------------------
# Epoch: 37  Train Loss: 3.4325  Valid Loss: 2.8525
# --------------------------------------------------
#
# Minimum Validation Loss of 2.8525 at epoch 37/100
# Model Saved
#
# Total Elapsed Time : 144.85427737236023 s
# Valid Steps: 186/186  Loss: 3.2607
# --------------------------------------------------
# Epoch: 38  Train Loss: 3.2614  Valid Loss: 3.2607
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.9253
# --------------------------------------------------
# Epoch: 39  Train Loss: 3.1351  Valid Loss: 2.9253
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.8371
# --------------------------------------------------
# Epoch: 40  Train Loss: 3.0589  Valid Loss: 2.8371
# --------------------------------------------------
#
# Minimum Validation Loss of 2.8371 at epoch 40/100
# Model Saved
#
# Total Elapsed Time : 143.0771746635437 s
# Valid Steps: 186/186  Loss: 2.9536
# --------------------------------------------------
# Epoch: 41  Train Loss: 2.9531  Valid Loss: 2.9536
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.8851
# --------------------------------------------------
# Epoch: 42  Train Loss: 2.9338  Valid Loss: 2.8851
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.5955
# --------------------------------------------------
# Epoch: 43  Train Loss: 2.8380  Valid Loss: 2.5955
# --------------------------------------------------
#
# Minimum Validation Loss of 2.5955 at epoch 43/100
# Model Saved
#
# Total Elapsed Time : 143.59360694885254 s
# Valid Steps: 186/186  Loss: 2.5798
# --------------------------------------------------
# Epoch: 44  Train Loss: 2.7900  Valid Loss: 2.5798
# --------------------------------------------------
#
# Minimum Validation Loss of 2.5798 at epoch 44/100
# Model Saved
#
# Total Elapsed Time : 144.8645966053009 s
# Valid Steps: 186/186  Loss: 2.8275
# --------------------------------------------------
# Epoch: 45  Train Loss: 2.7386  Valid Loss: 2.8275
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.3539
# --------------------------------------------------
# Epoch: 46  Train Loss: 2.6936  Valid Loss: 2.3539
# --------------------------------------------------
#
# Minimum Validation Loss of 2.3539 at epoch 46/100
# Model Saved
#
# Total Elapsed Time : 144.98160552978516 s
# Valid Steps: 186/186  Loss: 2.8674
# --------------------------------------------------
# Epoch: 47  Train Loss: 2.6552  Valid Loss: 2.8674
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.4617
# --------------------------------------------------
# Epoch: 48  Train Loss: 2.6004  Valid Loss: 2.4617
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.5699
# --------------------------------------------------
# Epoch: 49  Train Loss: 2.5301  Valid Loss: 2.5699
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.3499
# --------------------------------------------------
# Epoch: 50  Train Loss: 2.4556  Valid Loss: 2.3499
# --------------------------------------------------
#
# Minimum Validation Loss of 2.3499 at epoch 50/100
# Model Saved
#
# Total Elapsed Time : 147.89695811271667 s
# Valid Steps: 186/186  Loss: 2.4165
# --------------------------------------------------
# Epoch: 51  Train Loss: 2.4695  Valid Loss: 2.4165
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.1692
# --------------------------------------------------
# Epoch: 52  Train Loss: 2.4027  Valid Loss: 2.1692
# --------------------------------------------------
#
# Minimum Validation Loss of 2.1692 at epoch 52/100
# Model Saved
#
# Total Elapsed Time : 148.63416409492493 s
# Valid Steps: 186/186  Loss: 2.5423
# --------------------------------------------------
# Epoch: 53  Train Loss: 2.3297  Valid Loss: 2.5423
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.1828
# --------------------------------------------------
# Epoch: 54  Train Loss: 2.2728  Valid Loss: 2.1828
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.4541
# --------------------------------------------------
# Epoch: 55  Train Loss: 2.2413  Valid Loss: 2.4541
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.1033
# --------------------------------------------------
# Epoch: 56  Train Loss: 2.2116  Valid Loss: 2.1033
# --------------------------------------------------
#
# Minimum Validation Loss of 2.1033 at epoch 56/100
# Model Saved
#
# Total Elapsed Time : 153.25813579559326 s
# Valid Steps: 186/186  Loss: 2.0079
# --------------------------------------------------
# Epoch: 57  Train Loss: 2.1663  Valid Loss: 2.0079
# --------------------------------------------------
#
# Minimum Validation Loss of 2.0079 at epoch 57/100
# Model Saved
#
# Total Elapsed Time : 148.83523297309875 s
# Valid Steps: 186/186  Loss: 2.0725
# --------------------------------------------------
# Epoch: 58  Train Loss: 2.1342  Valid Loss: 2.0725
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9012
# --------------------------------------------------
# Epoch: 59  Train Loss: 2.1073  Valid Loss: 1.9012
# --------------------------------------------------
#
# Minimum Validation Loss of 1.9012 at epoch 59/100
# Model Saved
#
# Total Elapsed Time : 149.04823637008667 s
# Valid Steps: 186/186  Loss: 1.9862
# --------------------------------------------------
# Epoch: 60  Train Loss: 2.0360  Valid Loss: 1.9862
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.0529
# --------------------------------------------------
# Epoch: 61  Train Loss: 1.9917  Valid Loss: 2.0529
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9326
# --------------------------------------------------
# Epoch: 62  Train Loss: 2.0726  Valid Loss: 1.9326
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9436
# --------------------------------------------------
# Epoch: 63  Train Loss: 2.0107  Valid Loss: 1.9436
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9188
# --------------------------------------------------
# Epoch: 64  Train Loss: 2.0069  Valid Loss: 1.9188
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7726
# --------------------------------------------------
# Epoch: 65  Train Loss: 2.0210  Valid Loss: 1.7726
# --------------------------------------------------
#
# Minimum Validation Loss of 1.7726 at epoch 65/100
# Model Saved
#
# Total Elapsed Time : 148.18182158470154 s
# Valid Steps: 186/186  Loss: 2.0426
# --------------------------------------------------
# Epoch: 66  Train Loss: 1.9352  Valid Loss: 2.0426
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9853
# --------------------------------------------------
# Epoch: 67  Train Loss: 1.9576  Valid Loss: 1.9853
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7329
# --------------------------------------------------
# Epoch: 68  Train Loss: 1.9234  Valid Loss: 1.7329
# --------------------------------------------------
#
# Minimum Validation Loss of 1.7329 at epoch 68/100
# Model Saved
#
# Total Elapsed Time : 163.65488386154175 s
# Valid Steps: 186/186  Loss: 1.7494
# --------------------------------------------------
# Epoch: 69  Train Loss: 1.8876  Valid Loss: 1.7494
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.8474
# --------------------------------------------------
# Epoch: 70  Train Loss: 1.8568  Valid Loss: 1.8474
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.0024
# --------------------------------------------------
# Epoch: 71  Train Loss: 1.8241  Valid Loss: 2.0024
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.3269
# --------------------------------------------------
# Epoch: 72  Train Loss: 1.8485  Valid Loss: 2.3269
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.0039
# --------------------------------------------------
# Epoch: 73  Train Loss: 1.8353  Valid Loss: 2.0039
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.8116
# --------------------------------------------------
# Epoch: 74  Train Loss: 1.7932  Valid Loss: 1.8116
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 2.0141
# --------------------------------------------------
# Epoch: 75  Train Loss: 1.8458  Valid Loss: 2.0141
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9395
# --------------------------------------------------
# Epoch: 76  Train Loss: 1.7823  Valid Loss: 1.9395
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9155
# --------------------------------------------------
# Epoch: 77  Train Loss: 1.7941  Valid Loss: 1.9155
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7807
# --------------------------------------------------
# Epoch: 78  Train Loss: 1.7701  Valid Loss: 1.7807
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7503
# --------------------------------------------------
# Epoch: 79  Train Loss: 1.7558  Valid Loss: 1.7503
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9874
# --------------------------------------------------
# Epoch: 80  Train Loss: 1.7035  Valid Loss: 1.9874
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.8354
# --------------------------------------------------
# Epoch: 81  Train Loss: 1.6720  Valid Loss: 1.8354
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7759
# --------------------------------------------------
# Epoch: 82  Train Loss: 1.7035  Valid Loss: 1.7759
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9524
# --------------------------------------------------
# Epoch: 83  Train Loss: 1.6925  Valid Loss: 1.9524
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9498
# --------------------------------------------------
# Epoch: 84  Train Loss: 1.6266  Valid Loss: 1.9498
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6766
# --------------------------------------------------
# Epoch: 85  Train Loss: 1.6483  Valid Loss: 1.6766
# --------------------------------------------------
#
# Minimum Validation Loss of 1.6766 at epoch 85/100
# Model Saved
#
# Total Elapsed Time : 147.68022775650024 s
# Valid Steps: 186/186  Loss: 1.8419
# --------------------------------------------------
# Epoch: 86  Train Loss: 1.6581  Valid Loss: 1.8419
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6978
# --------------------------------------------------
# Epoch: 87  Train Loss: 1.6183  Valid Loss: 1.6978
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.5837
# --------------------------------------------------
# Epoch: 88  Train Loss: 1.6040  Valid Loss: 1.5837
# --------------------------------------------------
#
# Minimum Validation Loss of 1.5837 at epoch 88/100
# Model Saved
#
# Total Elapsed Time : 148.38323259353638 s
# Valid Steps: 186/186  Loss: 1.6678
# --------------------------------------------------
# Epoch: 89  Train Loss: 1.5658  Valid Loss: 1.6678
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6966
# --------------------------------------------------
# Epoch: 90  Train Loss: 1.5451  Valid Loss: 1.6966
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7641
# --------------------------------------------------
# Epoch: 91  Train Loss: 1.5644  Valid Loss: 1.7641
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6501
# --------------------------------------------------
# Epoch: 92  Train Loss: 1.5270  Valid Loss: 1.6501
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6977
# --------------------------------------------------
# Epoch: 93  Train Loss: 1.5479  Valid Loss: 1.6977
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.9799
# --------------------------------------------------
# Epoch: 94  Train Loss: 1.5232  Valid Loss: 1.9799
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6756
# --------------------------------------------------
# Epoch: 95  Train Loss: 1.5130  Valid Loss: 1.6756
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7206
# --------------------------------------------------
# Epoch: 96  Train Loss: 1.4789  Valid Loss: 1.7206
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6647
# --------------------------------------------------
# Epoch: 97  Train Loss: 1.4682  Valid Loss: 1.6647
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.8003
# --------------------------------------------------
# Epoch: 98  Train Loss: 1.4881  Valid Loss: 1.8003
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.7533
# --------------------------------------------------
# Epoch: 99  Train Loss: 1.4444  Valid Loss: 1.7533
# --------------------------------------------------
# Valid Steps: 186/186  Loss: 1.6126
# --------------------------------------------------
# Epoch: 100  Train Loss: 1.4521  Valid Loss: 1.6126
# --------------------------------------------------
# Training Complete
# Total Elapsed Time : 14704.290207386017 s

# %%
import csv
with open('Vacancy_3_epochs.csv', 'w', newline='') as f: 
    writer = csv.writer(f) 
    writer.writerow(train_losses) 
    writer.writerow(valid_losses)

# %%
is_closing = True;
dataset_closed = FaceLandmarksDataset(Transforms())

# %%
# split the dataset into validation and test sets
len_valid_set = int(0.1*len(dataset_closed))
len_train_set = len(dataset_closed) - len_valid_set

print("The length of Train set is {}".format(len_train_set))
print("The length of Valid set is {}".format(len_valid_set))

train_dataset , valid_dataset,  = torch.utils.data.random_split(dataset_closed , [len_train_set, len_valid_set])

# shuffle and batch the datasets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=2, shuffle=True, num_workers=0)
# Out:
# The length of Train set is 86
# The length of Valid set is 9

# %%
torch.autograd.set_detect_anomaly(True)
network = Network()
network.cuda()
network.load_state_dict(torch.load('./Vacancy_3.pth'))
network.eval()
network.cuda() 

criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(network.parameters(), lr=0.0002)

loss_min = np.inf
num_epochs = 20

start_time = time.time()
train_losses = []
valid_losses = []
for epoch in range(1,num_epochs+1):
    epoch_time = time.time()
    loss_train = 0
    loss_valid = 0
    running_loss = 0
    
    network.train()
    for step in range(1,len(train_loader)+1):
    
        images, landmarks = next(iter(train_loader))
        
        images = images.cuda()
        landmarks = landmarks.view(landmarks.size(0),-1).cuda() 
        
        predictions = network(images)
        
        # clear all the gradients before calculating them
        optimizer.zero_grad()
        
        # find the loss for the current step
        loss_train_step = criterion(predictions, landmarks)
        
        # calculate the gradients
        loss_train_step.backward()
        
        # update the parameters
        optimizer.step()
        
        loss_train += loss_train_step.item()
        running_loss = loss_train/step
        
        print_overwrite(step, len(train_loader), running_loss, 'train')
        
    network.eval() 
    with torch.no_grad():
        
        for step in range(1,len(valid_loader)+1):
            
            images, landmarks = next(iter(valid_loader))
        
            images = images.cuda()
            landmarks = landmarks.view(landmarks.size(0),-1).cuda()
        
            predictions = network(images)

            # find the loss for the current step
            loss_valid_step = criterion(predictions, landmarks)

            loss_valid += loss_valid_step.item()
            running_loss = loss_valid/step

            print_overwrite(step, len(valid_loader), running_loss, 'valid')
    
    loss_train /= len(train_loader)
    loss_valid /= len(valid_loader)
    train_losses.insert(epoch, loss_train)
    valid_losses.insert(epoch, loss_valid)
    print('\n--------------------------------------------------')
    print('Epoch: {}  Train Loss: {:.4f}  Valid Loss: {:.4f}'.format(epoch, loss_train, loss_valid))
    print('--------------------------------------------------')
    
    if loss_valid < loss_min:
        loss_min = loss_valid
        torch.save(network.state_dict(), 'Vacancy_6.th') # 1 : dataset : 300W & openCVDNN, network : resnet34(3,1,2), preprocess : 50% of openCVDNN
                                                          # 2 : dataset 3219->3816(multi-face images not ommitted)
                                                          # 3 : dataset split (open only)
                                                          # 4 : dataset split (open + closed), lr = 0.001
                                                          # 5 : dataset split ("), lr = 0.0002
                                                          # 6 : " with small epoch

        print("\nMinimum Validation Loss of {:.4f} at epoch {}/{}".format(loss_min, epoch, num_epochs))
        print('Model Saved\n')
        print("Total Elapsed Time : {} s".format(time.time()-epoch_time))
     
print('Training Complete')
print("Total Elapsed Time : {} s".format(time.time()-start_time))
# Out:
# Valid Steps: 5/5  Loss: 3.9175
# --------------------------------------------------
# Epoch: 1  Train Loss: 4.1923  Valid Loss: 3.9175
# --------------------------------------------------
#
# Minimum Validation Loss of 3.9175 at epoch 1/20
# Model Saved
#
# Total Elapsed Time : 4.788314342498779 s
# Valid Steps: 5/5  Loss: 2.7721
# --------------------------------------------------
# Epoch: 2  Train Loss: 3.7139  Valid Loss: 2.7721
# --------------------------------------------------
#
# Minimum Validation Loss of 2.7721 at epoch 2/20
# Model Saved
#
# Total Elapsed Time : 4.306778907775879 s
# Valid Steps: 5/5  Loss: 3.3776
# --------------------------------------------------
# Epoch: 3  Train Loss: 3.7050  Valid Loss: 3.3776
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.3052
# --------------------------------------------------
# Epoch: 4  Train Loss: 2.9443  Valid Loss: 3.3052
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 2.9897
# --------------------------------------------------
# Epoch: 5  Train Loss: 2.9354  Valid Loss: 2.9897
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 2.7653
# --------------------------------------------------
# Epoch: 6  Train Loss: 3.8084  Valid Loss: 2.7653
# --------------------------------------------------
#
# Minimum Validation Loss of 2.7653 at epoch 6/20
# Model Saved
#
# Total Elapsed Time : 4.082656621932983 s
# Valid Steps: 5/5  Loss: 3.3694
# --------------------------------------------------
# Epoch: 7  Train Loss: 2.6269  Valid Loss: 3.3694
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.5138
# --------------------------------------------------
# Epoch: 8  Train Loss: 2.8707  Valid Loss: 3.5138
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.2334
# --------------------------------------------------
# Epoch: 9  Train Loss: 2.8147  Valid Loss: 3.2334
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 2.9204
# --------------------------------------------------
# Epoch: 10  Train Loss: 2.2828  Valid Loss: 2.9204
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.2025
# --------------------------------------------------
# Epoch: 11  Train Loss: 2.8369  Valid Loss: 3.2025
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 2.5293
# --------------------------------------------------
# Epoch: 12  Train Loss: 3.3280  Valid Loss: 2.5293
# --------------------------------------------------
#
# Minimum Validation Loss of 2.5293 at epoch 12/20
# Model Saved
#
# Total Elapsed Time : 4.449677467346191 s
# Valid Steps: 5/5  Loss: 2.8158
# --------------------------------------------------
# Epoch: 13  Train Loss: 2.7827  Valid Loss: 2.8158
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.2593
# --------------------------------------------------
# Epoch: 14  Train Loss: 2.6792  Valid Loss: 3.2593
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.3399
# --------------------------------------------------
# Epoch: 15  Train Loss: 2.8136  Valid Loss: 3.3399
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.3284
# --------------------------------------------------
# Epoch: 16  Train Loss: 3.4519  Valid Loss: 3.3284
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.1724
# --------------------------------------------------
# Epoch: 17  Train Loss: 3.2501  Valid Loss: 3.1724
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 3.6438
# --------------------------------------------------
# Epoch: 18  Train Loss: 3.0445  Valid Loss: 3.6438
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 2.7844
# --------------------------------------------------
# Epoch: 19  Train Loss: 2.4657  Valid Loss: 2.7844
# --------------------------------------------------
# Valid Steps: 5/5  Loss: 2.9444
# --------------------------------------------------
# Epoch: 20  Train Loss: 3.4833  Valid Loss: 2.9444
# --------------------------------------------------
# Training Complete
# Total Elapsed Time : 85.53715491294861 s

# %%
import csv
with open('Vacancy_6_epochs.csv', 'w', newline='') as f: 
    writer = csv.writer(f) 
    writer.writerow(train_losses) 
    writer.writerow(valid_losses)
