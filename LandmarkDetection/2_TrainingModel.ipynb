# %%
import time
import cv2
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import imutils
import matplotlib.image as mpimg
from collections import OrderedDict
from skimage import io, transform
from math import *
import xml.etree.ElementTree as ET 

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from torchvision import datasets, models, transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class Transforms():
    def __init__(self):
        pass
    
    def rotate(self, image, landmarks, angle):
        angle = random.uniform(-angle, +angle)

        transformation_matrix = torch.tensor([
            [+cos(radians(angle)), -sin(radians(angle))], 
            [+sin(radians(angle)), +cos(radians(angle))]
        ])

        image = imutils.rotate(np.array(image), angle)

        landmarks = landmarks - 112
        new_landmarks = np.matmul(landmarks, transformation_matrix)
        new_landmarks = new_landmarks + 112
        return Image.fromarray(image), new_landmarks

    def resize(self, image, landmarks, img_size):
        ###
        landmarks = landmarks / torch.tensor([np.array(image).shape[0]/224, np.array(image).shape[0]/224])
        ###
        image = TF.resize(image, img_size)
        return image, landmarks

    def color_jitter(self, image, landmarks):
        color_jitter = transforms.ColorJitter(brightness=0.3, 
                                              contrast=0.3,
                                              saturation=0.3, 
                                              hue=0.1)
        image = color_jitter(image)
        return image, landmarks

    def crop_face(self, image, landmarks, crops):
        left = int(crops['left'])
        top = int(crops['top'])
        width = int(crops['width'])
        height = int(crops['height'])
        
        if(width > height) :
            left = left - width*0.25
            top = top + height*0.5 - width*0.5 - width*0.25
            width = width*1.5
            height = width
        else :
            top = top - height*0.25
            left = left + width*0.5 - height*0.5 - height*0.25
            height = height*1.5
            width = height

        image = TF.crop(image, top, left, height, width)
        
        img_shape = np.array(image).shape
        landmarks = torch.tensor(landmarks) - torch.tensor([[left, top]])
        #landmarks = landmarks / torch.tensor([img_shape[1], img_shape[0]])
        return image, landmarks

    def __call__(self, image, landmarks, crops):
        image = Image.fromarray(image)
        image, landmarks = self.crop_face(image, landmarks, crops)
        image, landmarks = self.resize(image, landmarks, (224, 224))
        image, landmarks = self.color_jitter(image, landmarks)
        image, landmarks = self.rotate(image, landmarks, angle=10)
        
        image = TF.to_tensor(image)
        image = TF.normalize(image, [0.5], [0.5])
        
        return image, landmarks

# %%
class FaceLandmarksDataset(Dataset):

    def __init__(self, transform=None):
        tree = ET.parse('./300W/labels_300W_new.xml')
        root = tree.getroot()

        self.image_filenames = []
        self.landmarks = []
        self.crops = []
        self.transform = transform
        self.root_dir= './300W'
        
        
        index_k = 0
        for filename in root[0]:
            landmark = []
            for num in range(68):
                x_coordinate = int(filename[0][num].attrib['x'])
                y_coordinate = int(filename[0][num].attrib['y'])
                landmark.append([x_coordinate, y_coordinate])
            
            y_l = landmark[37][1], landmark[41][1], landmark[38][1], landmark[40][1]  # left eye
            y_r = landmark[43][1], landmark[47][1], landmark[44][1], landmark[46][1]  # right eye
            y_n = landmark[33][1], landmark[51][1] # nose tip to top of mouth
            avg = 0
            for j in range(2) :
                avg = avg - y_l[2*j] + y_l[2*j+1] - y_r[2*j] + y_r[2*j+1]
            avg = avg/4
            val = avg/(-y_n[0]+y_n[1])
            
            if val> 0.2:
                index_k += 1
                self.image_filenames.append(os.path.join(self.root_dir, filename.attrib['file']))
                self.crops.append(filename[0].attrib)
                self.landmarks.append(landmark)                
            elif val <= 0.2:
                for i in range(38) :
                    self.image_filenames.append(os.path.join(self.root_dir, filename.attrib['file']))
                    self.crops.append(filename[0].attrib)
                    self.landmarks.append(landmark)

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, index):
        image = cv2.imread(self.image_filenames[index], 0)
        landmarks = self.landmarks[index]
        
        if self.transform:
            image, landmarks = self.transform(image, landmarks, self.crops[index])

        #landmarks = landmarks - 0.5

        return image, landmarks
dataset_open = FaceLandmarksDataset(Transforms())

# %%
# split the dataset into validation and test sets
len_valid_set = int(0.1*len(dataset_open))
len_train_set = len(dataset_open) - len_valid_set

print("The length of Train set is {}".format(len_train_set))
print("The length of Valid set is {}".format(len_valid_set))

train_dataset , valid_dataset,  = torch.utils.data.random_split(dataset_open , [len_train_set, len_valid_set])

# shuffle and batch the datasets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=2, shuffle=True, num_workers=0)
# Out:
# The length of Train set is 6589
# The length of Valid set is 732

# %%
images, landmarks = next(iter(train_loader))
plt.figure(figsize=(600/100, 600/100), dpi=100)
plt.scatter(landmarks[0,:,0], landmarks[0,:,1], c = 'g', s = 10)
plt.imshow(images[0].cpu().numpy().transpose(1,2,0).squeeze(), cmap='gray')

# %%
class Network(nn.Module):
    def __init__(self,num_classes=136):
        super().__init__()
        self.model_name='resnet34'
        self.model=models.resnet34(pretrained=False)
        #self.model.conv1=nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.model.conv1=nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=2, bias=False)
        self.model.fc=nn.Linear(self.model.fc.in_features, num_classes)
        
    def forward(self, x):
        x=self.model(x)
        return x

# %%
import sys

def print_overwrite(step, total_step, loss, operation):
    sys.stdout.write('\r')
    if operation == 'train':
        sys.stdout.write("Train Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))   
    else:
        sys.stdout.write("Valid Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))
        
    sys.stdout.flush()

# %%
torch.autograd.set_detect_anomaly(True)
network = Network()
network.cuda()
#network.load_state_dict(torch.load('./Vacancy_9.pth'))
#network.eval()

criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(network.parameters(), lr=0.0001)

loss_min = np.inf
num_epochs = 100

start_time = time.time()
train_losses = []
valid_losses = []
for epoch in range(1,num_epochs+1):
    epoch_time = time.time()
    loss_train = 0
    loss_valid = 0
    running_loss = 0
    
    network.train()
    for step in range(1,len(train_loader)+1):
    
        images, landmarks = next(iter(train_loader))
        
        images = images.cuda()
        landmarks = landmarks.view(landmarks.size(0),-1).cuda()
        
        predictions = network(images)
        
        # clear all the gradients before calculating them
        optimizer.zero_grad()
        
        # find the loss for the current step
        loss_train_step = criterion(predictions, landmarks)
        
        # calculate the gradients
        loss_train_step.backward()
        
        # update the parameters
        optimizer.step()
        
        loss_train += loss_train_step.item()
        running_loss = loss_train/step
        
        print_overwrite(step, len(train_loader), running_loss, 'train')
        
    network.eval() 
    with torch.no_grad():
        
        for step in range(1,len(valid_loader)+1):
            
            images, landmarks = next(iter(valid_loader))
        
            images = images.cuda()
            landmarks = landmarks.view(landmarks.size(0),-1).cuda()
        
            predictions = network(images)

            # find the loss for the current step
            loss_valid_step = criterion(predictions, landmarks)

            loss_valid += loss_valid_step.item()
            running_loss = loss_valid/step

            print_overwrite(step, len(valid_loader), running_loss, 'valid')
    
    loss_train /= len(train_loader)
    loss_valid /= len(valid_loader)
    train_losses.insert(epoch, loss_train)
    valid_losses.insert(epoch, loss_valid)
    print('\n--------------------------------------------------')
    print('Epoch: {}  Train Loss: {:.4f}  Valid Loss: {:.4f}'.format(epoch, loss_train, loss_valid))
    print('--------------------------------------------------')
    
    if loss_valid < loss_min:
        loss_min = loss_valid
        torch.save(network.state_dict(), 'Vacancy_11.pth') # 1 : dataset : 300W & openCVDNN, network : resnet34(3,1,2), preprocess : 50% of openCVDNN
                                                          # 2 : dataset 3219->3816(multi-face images not ommitted)
                                                          # 3 : dataset split (open only)
                                                          # 7 : oversampling & downsampling (0.5 : 19)
                                                          # 8 : oversampling & downsampling (0.25 : 9)
                                                          # 9 : oversampling (1:39)
                                                          # 10 : oversampling (1:39) WITH 200 EPOCHS
                                                          # 11 : oversampling (1:39) with smaller kernel

        print("\nMinimum Validation Loss of {:.4f} at epoch {}/{}".format(loss_min, epoch, num_epochs))
        print('Model Saved\n')
        print("Total Elapsed Time : {} s".format(time.time()-epoch_time))
     
print('Training Complete')
print("Total Elapsed Time : {} s".format(time.time()-start_time))

import csv
with open('Vacancy_11_epochs.csv', 'w', newline='') as f: 
    writer = csv.writer(f) 
    writer.writerow(train_losses) 
    writer.writerow(valid_losses)
# Out:
# Valid Steps: 366/366  Loss: 67.8413
# --------------------------------------------------
# Epoch: 1  Train Loss: 94.5560  Valid Loss: 67.8413
# --------------------------------------------------
#
# Minimum Validation Loss of 67.8413 at epoch 1/100
# Model Saved
#
# Total Elapsed Time : 295.75660610198975 s
# Valid Steps: 366/366  Loss: 21.4604
# --------------------------------------------------
# Epoch: 2  Train Loss: 41.7087  Valid Loss: 21.4604
# --------------------------------------------------
#
# Minimum Validation Loss of 21.4604 at epoch 2/100
# Model Saved
#
# Total Elapsed Time : 289.6430652141571 s
# Valid Steps: 366/366  Loss: 8.8856
# --------------------------------------------------
# Epoch: 3  Train Loss: 12.4506  Valid Loss: 8.8856
# --------------------------------------------------
#
# Minimum Validation Loss of 8.8856 at epoch 3/100
# Model Saved
#
# Total Elapsed Time : 289.20433044433594 s
# Valid Steps: 366/366  Loss: 8.5864
# --------------------------------------------------
# Epoch: 4  Train Loss: 8.6753  Valid Loss: 8.5864
# --------------------------------------------------
#
# Minimum Validation Loss of 8.5864 at epoch 4/100
# Model Saved
#
# Total Elapsed Time : 289.1169295310974 s
# Valid Steps: 366/366  Loss: 8.6363
# --------------------------------------------------
# Epoch: 5  Train Loss: 8.7135  Valid Loss: 8.6363
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 8.5048
# --------------------------------------------------
# Epoch: 6  Train Loss: 8.5779  Valid Loss: 8.5048
# --------------------------------------------------
#
# Minimum Validation Loss of 8.5048 at epoch 6/100
# Model Saved
#
# Total Elapsed Time : 288.726172208786 s
# Valid Steps: 366/366  Loss: 8.5106
# --------------------------------------------------
# Epoch: 7  Train Loss: 8.5169  Valid Loss: 8.5106
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 8.5853
# --------------------------------------------------
# Epoch: 8  Train Loss: 8.5019  Valid Loss: 8.5853
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 8.6666
# --------------------------------------------------
# Epoch: 9  Train Loss: 8.5596  Valid Loss: 8.6666
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 8.7866
# --------------------------------------------------
# Epoch: 10  Train Loss: 8.7068  Valid Loss: 8.7866
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 8.5028
# --------------------------------------------------
# Epoch: 11  Train Loss: 8.6481  Valid Loss: 8.5028
# --------------------------------------------------
#
# Minimum Validation Loss of 8.5028 at epoch 11/100
# Model Saved
#
# Total Elapsed Time : 290.2960133552551 s
# Valid Steps: 366/366  Loss: 8.2044
# --------------------------------------------------
# Epoch: 12  Train Loss: 8.5053  Valid Loss: 8.2044
# --------------------------------------------------
#
# Minimum Validation Loss of 8.2044 at epoch 12/100
# Model Saved
#
# Total Elapsed Time : 288.91652941703796 s
# Valid Steps: 366/366  Loss: 8.6384
# --------------------------------------------------
# Epoch: 13  Train Loss: 8.4727  Valid Loss: 8.6384
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 8.1366
# --------------------------------------------------
# Epoch: 14  Train Loss: 8.4365  Valid Loss: 8.1366
# --------------------------------------------------
#
# Minimum Validation Loss of 8.1366 at epoch 14/100
# Model Saved
#
# Total Elapsed Time : 322.21022868156433 s
# Valid Steps: 366/366  Loss: 8.0847
# --------------------------------------------------
# Epoch: 15  Train Loss: 8.1163  Valid Loss: 8.0847
# --------------------------------------------------
#
# Minimum Validation Loss of 8.0847 at epoch 15/100
# Model Saved
#
# Total Elapsed Time : 308.4390015602112 s
# Valid Steps: 366/366  Loss: 7.1395
# --------------------------------------------------
# Epoch: 16  Train Loss: 7.6239  Valid Loss: 7.1395
# --------------------------------------------------
#
# Minimum Validation Loss of 7.1395 at epoch 16/100
# Model Saved
#
# Total Elapsed Time : 299.2518820762634 s
# Valid Steps: 366/366  Loss: 6.9109
# --------------------------------------------------
# Epoch: 17  Train Loss: 7.0172  Valid Loss: 6.9109
# --------------------------------------------------
#
# Minimum Validation Loss of 6.9109 at epoch 17/100
# Model Saved
#
# Total Elapsed Time : 301.3329486846924 s
# Valid Steps: 366/366  Loss: 5.9472
# --------------------------------------------------
# Epoch: 18  Train Loss: 6.2425  Valid Loss: 5.9472
# --------------------------------------------------
#
# Minimum Validation Loss of 5.9472 at epoch 18/100
# Model Saved
#
# Total Elapsed Time : 285.5763478279114 s
# Valid Steps: 366/366  Loss: 5.2371
# --------------------------------------------------
# Epoch: 19  Train Loss: 5.4608  Valid Loss: 5.2371
# --------------------------------------------------
#
# Minimum Validation Loss of 5.2371 at epoch 19/100
# Model Saved
#
# Total Elapsed Time : 288.23512387275696 s
# Valid Steps: 366/366  Loss: 5.0562
# --------------------------------------------------
# Epoch: 20  Train Loss: 4.8484  Valid Loss: 5.0562
# --------------------------------------------------
#
# Minimum Validation Loss of 5.0562 at epoch 20/100
# Model Saved
#
# Total Elapsed Time : 286.34863901138306 s
# Valid Steps: 366/366  Loss: 3.9976
# --------------------------------------------------
# Epoch: 21  Train Loss: 4.4499  Valid Loss: 3.9976
# --------------------------------------------------
#
# Minimum Validation Loss of 3.9976 at epoch 21/100
# Model Saved
#
# Total Elapsed Time : 285.57517981529236 s
# Valid Steps: 366/366  Loss: 4.1314
# --------------------------------------------------
# Epoch: 22  Train Loss: 4.1752  Valid Loss: 4.1314
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 3.6622
# --------------------------------------------------
# Epoch: 23  Train Loss: 3.8894  Valid Loss: 3.6622
# --------------------------------------------------
#
# Minimum Validation Loss of 3.6622 at epoch 23/100
# Model Saved
#
# Total Elapsed Time : 288.4442217350006 s
# Valid Steps: 366/366  Loss: 3.4846
# --------------------------------------------------
# Epoch: 24  Train Loss: 3.8686  Valid Loss: 3.4846
# --------------------------------------------------
#
# Minimum Validation Loss of 3.4846 at epoch 24/100
# Model Saved
#
# Total Elapsed Time : 285.0158257484436 s
# Valid Steps: 366/366  Loss: 2.9677
# --------------------------------------------------
# Epoch: 25  Train Loss: 3.6710  Valid Loss: 2.9677
# --------------------------------------------------
#
# Minimum Validation Loss of 2.9677 at epoch 25/100
# Model Saved
#
# Total Elapsed Time : 288.23171615600586 s
# Valid Steps: 366/366  Loss: 2.8859
# --------------------------------------------------
# Epoch: 26  Train Loss: 3.5025  Valid Loss: 2.8859
# --------------------------------------------------
#
# Minimum Validation Loss of 2.8859 at epoch 26/100
# Model Saved
#
# Total Elapsed Time : 288.8198809623718 s
# Valid Steps: 366/366  Loss: 2.7273
# --------------------------------------------------
# Epoch: 27  Train Loss: 3.3384  Valid Loss: 2.7273
# --------------------------------------------------
#
# Minimum Validation Loss of 2.7273 at epoch 27/100
# Model Saved
#
# Total Elapsed Time : 287.6886742115021 s
# Valid Steps: 366/366  Loss: 2.6691
# --------------------------------------------------
# Epoch: 28  Train Loss: 3.1989  Valid Loss: 2.6691
# --------------------------------------------------
#
# Minimum Validation Loss of 2.6691 at epoch 28/100
# Model Saved
#
# Total Elapsed Time : 285.65368390083313 s
# Valid Steps: 366/366  Loss: 2.5070
# --------------------------------------------------
# Epoch: 29  Train Loss: 3.0594  Valid Loss: 2.5070
# --------------------------------------------------
#
# Minimum Validation Loss of 2.5070 at epoch 29/100
# Model Saved
#
# Total Elapsed Time : 287.45982027053833 s
# Valid Steps: 366/366  Loss: 2.7012
# --------------------------------------------------
# Epoch: 30  Train Loss: 2.9581  Valid Loss: 2.7012
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.5095
# --------------------------------------------------
# Epoch: 31  Train Loss: 2.8620  Valid Loss: 2.5095
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.6559
# --------------------------------------------------
# Epoch: 32  Train Loss: 2.8166  Valid Loss: 2.6559
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.4138
# --------------------------------------------------
# Epoch: 33  Train Loss: 2.6624  Valid Loss: 2.4138
# --------------------------------------------------
#
# Minimum Validation Loss of 2.4138 at epoch 33/100
# Model Saved
#
# Total Elapsed Time : 287.9250102043152 s
# Valid Steps: 366/366  Loss: 2.8448
# --------------------------------------------------
# Epoch: 34  Train Loss: 2.5774  Valid Loss: 2.8448
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.8391
# --------------------------------------------------
# Epoch: 35  Train Loss: 2.5675  Valid Loss: 2.8391
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.1566
# --------------------------------------------------
# Epoch: 36  Train Loss: 2.4580  Valid Loss: 2.1566
# --------------------------------------------------
#
# Minimum Validation Loss of 2.1566 at epoch 36/100
# Model Saved
#
# Total Elapsed Time : 289.20388746261597 s
# Valid Steps: 366/366  Loss: 2.1314
# --------------------------------------------------
# Epoch: 37  Train Loss: 2.3337  Valid Loss: 2.1314
# --------------------------------------------------
#
# Minimum Validation Loss of 2.1314 at epoch 37/100
# Model Saved
#
# Total Elapsed Time : 289.75795102119446 s
# Valid Steps: 366/366  Loss: 2.4778
# --------------------------------------------------
# Epoch: 38  Train Loss: 2.3339  Valid Loss: 2.4778
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.0115
# --------------------------------------------------
# Epoch: 39  Train Loss: 2.2749  Valid Loss: 2.0115
# --------------------------------------------------
#
# Minimum Validation Loss of 2.0115 at epoch 39/100
# Model Saved
#
# Total Elapsed Time : 288.65943145751953 s
# Valid Steps: 366/366  Loss: 2.1017
# --------------------------------------------------
# Epoch: 40  Train Loss: 2.2566  Valid Loss: 2.1017
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.9695
# --------------------------------------------------
# Epoch: 41  Train Loss: 2.2124  Valid Loss: 1.9695
# --------------------------------------------------
#
# Minimum Validation Loss of 1.9695 at epoch 41/100
# Model Saved
#
# Total Elapsed Time : 297.3665232658386 s
# Valid Steps: 366/366  Loss: 2.0564
# --------------------------------------------------
# Epoch: 42  Train Loss: 2.1479  Valid Loss: 2.0564
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.2914
# --------------------------------------------------
# Epoch: 43  Train Loss: 2.0958  Valid Loss: 2.2914
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 2.0257
# --------------------------------------------------
# Epoch: 44  Train Loss: 2.0680  Valid Loss: 2.0257
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.8648
# --------------------------------------------------
# Epoch: 45  Train Loss: 2.0094  Valid Loss: 1.8648
# --------------------------------------------------
#
# Minimum Validation Loss of 1.8648 at epoch 45/100
# Model Saved
#
# Total Elapsed Time : 302.2687644958496 s
# Valid Steps: 366/366  Loss: 1.8704
# --------------------------------------------------
# Epoch: 46  Train Loss: 1.9437  Valid Loss: 1.8704
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.9716
# --------------------------------------------------
# Epoch: 47  Train Loss: 1.9026  Valid Loss: 1.9716
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.8945
# --------------------------------------------------
# Epoch: 48  Train Loss: 1.8599  Valid Loss: 1.8945
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.6560
# --------------------------------------------------
# Epoch: 49  Train Loss: 1.8671  Valid Loss: 1.6560
# --------------------------------------------------
#
# Minimum Validation Loss of 1.6560 at epoch 49/100
# Model Saved
#
# Total Elapsed Time : 288.35794711112976 s
# Valid Steps: 366/366  Loss: 2.0587
# --------------------------------------------------
# Epoch: 50  Train Loss: 1.7781  Valid Loss: 2.0587
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.7395
# --------------------------------------------------
# Epoch: 51  Train Loss: 1.7899  Valid Loss: 1.7395
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.7973
# --------------------------------------------------
# Epoch: 52  Train Loss: 1.7281  Valid Loss: 1.7973
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.7513
# --------------------------------------------------
# Epoch: 53  Train Loss: 1.7289  Valid Loss: 1.7513
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.6100
# --------------------------------------------------
# Epoch: 54  Train Loss: 1.6819  Valid Loss: 1.6100
# --------------------------------------------------
#
# Minimum Validation Loss of 1.6100 at epoch 54/100
# Model Saved
#
# Total Elapsed Time : 288.2599196434021 s
# Valid Steps: 366/366  Loss: 1.6736
# --------------------------------------------------
# Epoch: 55  Train Loss: 1.6311  Valid Loss: 1.6736
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.5875
# --------------------------------------------------
# Epoch: 56  Train Loss: 1.6158  Valid Loss: 1.5875
# --------------------------------------------------
#
# Minimum Validation Loss of 1.5875 at epoch 56/100
# Model Saved
#
# Total Elapsed Time : 291.4828724861145 s
# Valid Steps: 366/366  Loss: 1.5829
# --------------------------------------------------
# Epoch: 57  Train Loss: 1.5675  Valid Loss: 1.5829
# --------------------------------------------------
#
# Minimum Validation Loss of 1.5829 at epoch 57/100
# Model Saved
#
# Total Elapsed Time : 289.0869028568268 s
# Valid Steps: 366/366  Loss: 1.5337
# --------------------------------------------------
# Epoch: 58  Train Loss: 1.5824  Valid Loss: 1.5337
# --------------------------------------------------
#
# Minimum Validation Loss of 1.5337 at epoch 58/100
# Model Saved
#
# Total Elapsed Time : 297.6319406032562 s
# Valid Steps: 366/366  Loss: 1.6349
# --------------------------------------------------
# Epoch: 59  Train Loss: 1.5461  Valid Loss: 1.6349
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.6104
# --------------------------------------------------
# Epoch: 60  Train Loss: 1.5159  Valid Loss: 1.6104
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.6764
# --------------------------------------------------
# Epoch: 61  Train Loss: 1.4803  Valid Loss: 1.6764
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.5378
# --------------------------------------------------
# Epoch: 62  Train Loss: 1.5116  Valid Loss: 1.5378
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.3972
# --------------------------------------------------
# Epoch: 63  Train Loss: 1.4567  Valid Loss: 1.3972
# --------------------------------------------------
#
# Minimum Validation Loss of 1.3972 at epoch 63/100
# Model Saved
#
# Total Elapsed Time : 298.59587264060974 s
# Valid Steps: 366/366  Loss: 1.5101
# --------------------------------------------------
# Epoch: 64  Train Loss: 1.4352  Valid Loss: 1.5101
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.5168
# --------------------------------------------------
# Epoch: 65  Train Loss: 1.4094  Valid Loss: 1.5168
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.5791
# --------------------------------------------------
# Epoch: 66  Train Loss: 1.4153  Valid Loss: 1.5791
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.4813
# --------------------------------------------------
# Epoch: 67  Train Loss: 1.3630  Valid Loss: 1.4813
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2901
# --------------------------------------------------
# Epoch: 68  Train Loss: 1.3634  Valid Loss: 1.2901
# --------------------------------------------------
#
# Minimum Validation Loss of 1.2901 at epoch 68/100
# Model Saved
#
# Total Elapsed Time : 294.90257239341736 s
# Valid Steps: 366/366  Loss: 1.3929
# --------------------------------------------------
# Epoch: 69  Train Loss: 1.3514  Valid Loss: 1.3929
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.3715
# --------------------------------------------------
# Epoch: 70  Train Loss: 1.3068  Valid Loss: 1.3715
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.3801
# --------------------------------------------------
# Epoch: 71  Train Loss: 1.3506  Valid Loss: 1.3801
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.4209
# --------------------------------------------------
# Epoch: 72  Train Loss: 1.2923  Valid Loss: 1.4209
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.3062
# --------------------------------------------------
# Epoch: 73  Train Loss: 1.2721  Valid Loss: 1.3062
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.4227
# --------------------------------------------------
# Epoch: 74  Train Loss: 1.2735  Valid Loss: 1.4227
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2083
# --------------------------------------------------
# Epoch: 75  Train Loss: 1.2402  Valid Loss: 1.2083
# --------------------------------------------------
#
# Minimum Validation Loss of 1.2083 at epoch 75/100
# Model Saved
#
# Total Elapsed Time : 302.9057331085205 s
# Valid Steps: 366/366  Loss: 1.2481
# --------------------------------------------------
# Epoch: 76  Train Loss: 1.2270  Valid Loss: 1.2481
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.4394
# --------------------------------------------------
# Epoch: 77  Train Loss: 1.2053  Valid Loss: 1.4394
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.3760
# --------------------------------------------------
# Epoch: 78  Train Loss: 1.1754  Valid Loss: 1.3760
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.4818
# --------------------------------------------------
# Epoch: 79  Train Loss: 1.2018  Valid Loss: 1.4818
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.3741
# --------------------------------------------------
# Epoch: 80  Train Loss: 1.1792  Valid Loss: 1.3741
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.1821
# --------------------------------------------------
# Epoch: 81  Train Loss: 1.1779  Valid Loss: 1.1821
# --------------------------------------------------
#
# Minimum Validation Loss of 1.1821 at epoch 81/100
# Model Saved
#
# Total Elapsed Time : 300.4308512210846 s
# Valid Steps: 366/366  Loss: 1.1766
# --------------------------------------------------
# Epoch: 82  Train Loss: 1.1227  Valid Loss: 1.1766
# --------------------------------------------------
#
# Minimum Validation Loss of 1.1766 at epoch 82/100
# Model Saved
#
# Total Elapsed Time : 301.20326709747314 s
# Valid Steps: 366/366  Loss: 1.2624
# --------------------------------------------------
# Epoch: 83  Train Loss: 1.1060  Valid Loss: 1.2624
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2533
# --------------------------------------------------
# Epoch: 84  Train Loss: 1.1181  Valid Loss: 1.2533
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2457
# --------------------------------------------------
# Epoch: 85  Train Loss: 1.0883  Valid Loss: 1.2457
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.1955
# --------------------------------------------------
# Epoch: 86  Train Loss: 1.0921  Valid Loss: 1.1955
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2146
# --------------------------------------------------
# Epoch: 87  Train Loss: 1.1116  Valid Loss: 1.2146
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.3212
# --------------------------------------------------
# Epoch: 88  Train Loss: 1.0561  Valid Loss: 1.3212
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.1861
# --------------------------------------------------
# Epoch: 89  Train Loss: 1.0569  Valid Loss: 1.1861
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2521
# --------------------------------------------------
# Epoch: 90  Train Loss: 1.0667  Valid Loss: 1.2521
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.0911
# --------------------------------------------------
# Epoch: 91  Train Loss: 1.0211  Valid Loss: 1.0911
# --------------------------------------------------
#
# Minimum Validation Loss of 1.0911 at epoch 91/100
# Model Saved
#
# Total Elapsed Time : 363.23416447639465 s
# Valid Steps: 366/366  Loss: 1.2541
# --------------------------------------------------
# Epoch: 92  Train Loss: 1.0401  Valid Loss: 1.2541
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2091
# --------------------------------------------------
# Epoch: 93  Train Loss: 1.0236  Valid Loss: 1.2091
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.0751
# --------------------------------------------------
# Epoch: 94  Train Loss: 0.9905  Valid Loss: 1.0751
# --------------------------------------------------
#
# Minimum Validation Loss of 1.0751 at epoch 94/100
# Model Saved
#
# Total Elapsed Time : 350.00644159317017 s
# Valid Steps: 366/366  Loss: 1.1319
# --------------------------------------------------
# Epoch: 95  Train Loss: 1.0228  Valid Loss: 1.1319
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.1276
# --------------------------------------------------
# Epoch: 96  Train Loss: 0.9777  Valid Loss: 1.1276
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.2145
# --------------------------------------------------
# Epoch: 97  Train Loss: 0.9742  Valid Loss: 1.2145
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.1652
# --------------------------------------------------
# Epoch: 98  Train Loss: 0.9729  Valid Loss: 1.1652
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.1064
# --------------------------------------------------
# Epoch: 99  Train Loss: 0.9691  Valid Loss: 1.1064
# --------------------------------------------------
# Valid Steps: 366/366  Loss: 1.0312
# --------------------------------------------------
# Epoch: 100  Train Loss: 0.9605  Valid Loss: 1.0312
# --------------------------------------------------
#
# Minimum Validation Loss of 1.0312 at epoch 100/100
# Model Saved
#
# Total Elapsed Time : 347.0262944698334 s
# Training Complete
# Total Elapsed Time : 30441.91460776329 s
